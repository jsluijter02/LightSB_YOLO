# %% [markdown]
# # TSNE, PCA? Just show how the things are different between day/night and if theres a difference between that and val and test

# %% [markdown]
# Also train a little classifier that tells us whether theres a difference between the latents
