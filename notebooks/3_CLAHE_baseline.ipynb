# %% [markdown]
# # Baseline with Histogram Equalization Technique
# This notebook serves to estimate possible effectiveness of a Light Schrödinger Bridge technique and the possible ineffectiveness of simple brightness/contrast enhancing techniques, for instance, histogram equalization and the more sophisticated version CLAHE.
#
# ## Imports

# %%
import os, sys


# if colab, mount drive and get the git repo
if 'google.colab' in sys.modules:
    from google.colab import drive
    print(os.getcwd())
    drive.mount('/content/drive')
    # !git clone --recurse-submodules https://github.com/jsluijter02/LightSB_YOLO

    # Append LightSB_YOLO path
    sys.path.append(os.path.join(os.getcwd(), 'LightSB_YOLO'))

# otherwise local path append
else:
    sys.path.append(os.path.dirname(os.getcwd()))

# %%
from scripts.utils import dirs
dirs.add_YOLOPX_to_PATH()

import torchvision.transforms as transforms
import pickle as pkl
import copy
from argparse import Namespace
from tqdm import tqdm

import cv2
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

from scripts.models.yolo import YOLOPX_BDD
from scripts.dataset import bdd
from scripts.utils import img 

np.random.seed(0)

# %% [markdown]
# ## YOLO Model Initialization

# %%
model = YOLOPX_BDD()
# Out:
# AUTO_RESUME: False
# CUDNN:
#   BENCHMARK: True
#   DETERMINISTIC: False
#   ENABLED: True
# DATASET:
#   CLAHE_CLIPLIMIT: 2.0
#   CLAHE_VAL: False
#   COLOR_RGB: False
#   DATAROOT: c:\Users\joche\Development\Github\LightSB_YOLO\data\images
#   DATASET: BddDataset
#   DATA_FORMAT: jpg
#   FLIP: True
#   HSV_H: 0.015
#   HSV_S: 0.7
#   HSV_V: 0.4
#   LABELROOT: c:\Users\joche\Development\Github\LightSB_YOLO\data\bdd\det_annotations
#   LANEROOT: c:\Users\joche\Development\Github\LightSB_YOLO\data\bdd\ll_seg_annotations
#   MASKROOT: c:\Users\joche\Development\Github\LightSB_YOLO\data\bdd\da_seg_annotations
#   ORG_IMG_SIZE: [720, 1280]
#   ROT_FACTOR: 10
#   SCALE_FACTOR: 0.25
#   SELECT_DATA: False
#   SHEAR: 0.0
#   TEST_SET: val
#   TRAIN_SET: train
#   TRANSLATE: 0.1
# DEBUG: False
# GPUS: (0,)
# LOG_DIR: c:\Users\joche\Development\Github\LightSB_YOLO\results\logs
# LOSS:
#   BOX_GAIN: 0.05
#   CLS_GAIN: 0.5
#   CLS_POS_WEIGHT: 1.0
#   DA_SEG_GAIN: 0.2
#   FL_GAMMA: 2.0
#   LL_IOU_GAIN: 0.2
#   LL_SEG_GAIN: 0.2
#   LOSS_NAME:
#   MULTI_HEAD_LAMBDA: None
#   OBJ_GAIN: 1.0
#   OBJ_POS_WEIGHT: 1.0
#   SEG_POS_WEIGHT: 1.0
# METRICS_PER_IMAGE: True
# MODEL:
#   EXTRA:
#
#   HEADS_NAME: ['']
#   IMAGE_SIZE: [640, 640]
#   NAME:
#   PRETRAINED:
#   PRETRAINED_DET:
#   STRU_WITHSHARE: False
# NEED_AUTOANCHOR: False
# OUTPUT_DIR: c:\Users\joche\Development\Github\LightSB_YOLO\results
# PIN_MEMORY: True
# PRINT_FREQ: 2150
# TEST:
#   BATCH_SIZE_PER_GPU: 4
#   MODEL_FILE:
#   NMS_CONF_THRESHOLD: 0.001
#   NMS_IOU_THRESHOLD: 0.6
#   PLOTS: False
#   SAVE_JSON: False
#   SAVE_TXT: True
# TRAIN:
#   ANCHOR_THRESHOLD: 4.0
#   BATCH_SIZE_PER_GPU: 8
#   BEGIN_EPOCH: 0
#   DET_ONLY: False
#   DRIVABLE_ONLY: False
#   ENC_DET_ONLY: False
#   ENC_SEG_ONLY: False
#   END_EPOCH: 200
#   GAMMA1: 0.99
#   GAMMA2: 0.0
#   IOU_THRESHOLD: 0.2
#   LANE_ONLY: False
#   LR0: 0.001
#   LRF: 0.1
#   MOMENTUM: 0.937
#   NESTEROV: True
#   OPTIMIZER: adamw
#   PLOT: False
#   SEG_ONLY: False
#   SHUFFLE: True
#   VAL_FREQ: 20
#   WARMUP_BIASE_LR: 0.1
#   WARMUP_EPOCHS: 3.0
#   WARMUP_MOMENTUM: 0.8
#   WD: 0.0005
# WORKERS: 0
# mixup_rate: 0.15
# mosaic_rate: 0.0
# num_seg_class: 2
# => creating c:\Users\joche\Development\Github\LightSB_YOLO\results\logs\BddDataset\logs_2026-02-20-10-25
# c:\Users\joche\Development\Github\LightSB_YOLO\scripts\models\yolo.py:75: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(self.weights, map_location=self.device)

# %% [markdown]
# ## Sample Night Set Images

# %%
train_night_db = bdd.get_db(model.config, is_train=True, timeofday="night")

sample_indices = img.sample_indices(len(train_night_db), how_many=3)
print("sample indices: ", sample_indices)

save_path = os.path.join(dirs.get_base_dir(), 'results', '6_compare', 'CLAHE')
os.makedirs(save_path, exist_ok=True)
# Out:
# sample indices:  [11010 26205 17150]

# %% [markdown]
# ## HSV Image Histogram

# %%
# arbitrary night image
RGB_imgs = []
HSV_imgs= []
for index in sample_indices:
    night_img_path = train_night_db[index]['image']
    print(night_img_path)
    night_img = cv2.imread(night_img_path)
    RGB_imgs.append(cv2.cvtColor(night_img, cv2.COLOR_BGR2RGB))

    night_img_hsv = cv2.cvtColor(night_img, cv2.COLOR_BGR2HSV)
    HSV_imgs.append(night_img_hsv)

# img
plt.figure()
img.plot_samples(RGB_imgs, "Sample Night Images from Train Set", 
                 labels=[f"Index {i}" for i in sample_indices], square=False)
plt.savefig(os.path.join(save_path, 'trainnightsamples.png'))
plt.show()

plt.figure()
img.plot_samples([HSV_img[:,:,2] for HSV_img in HSV_imgs], 
                 title="HSV V-Channel Plot of Train Night Set Samples", 
                 labels= [f'Index {index}' for index in sample_indices], square= False)
plt.savefig(os.path.join(save_path, 'HSVnightsamples.png'))
plt.show()

## now plot the value (brightness levels) accross this night image
plt.figure(figsize=(11,3))
for i, image in enumerate(HSV_imgs):
    plt.subplot(1,3,i+1)
    plt.hist(image[:,:,2].ravel(),256,[0,256], color="darkblue")
    plt.ylabel("Pixel Count")
    plt.xlabel(f"Index {sample_indices[i]} HSV V-Channel Value")
plt.suptitle("HSV V-Channel Distribution on Sample Night Training Images")
plt.tight_layout()
plt.savefig(os.path.join(save_path, 'HSVhistogramnightsamples.png'))
plt.show()
# Out:
# c:\Users\joche\Development\Github\LightSB_YOLO\data\images\train\465b4176-967c2a5f.jpg
# c:\Users\joche\Development\Github\LightSB_YOLO\data\images\train\a7163c29-de130b38.jpg
# c:\Users\joche\Development\Github\LightSB_YOLO\data\images\train\6d226a88-0e6e431e.jpg

# %% [markdown]
# ## Regular Histogram Equalization

# %%
# source: https://www.geeksforgeeks.org/python/histograms-equalization-opencv/
# HISTOGRAM EQ
HE_imgs = []
for image in HSV_imgs:
    night_img_HE = copy.copy(image)
    night_img_HE[:,:,2] = cv2.equalizeHist(night_img_HE[:,:,2])
    HE_imgs.append(night_img_HE)

plt.figure()
img.plot_samples([cv2.cvtColor(HE_img, cv2.COLOR_HSV2RGB) for HE_img in HE_imgs], 
                 title= "Histogram Equalized HSV V-Channel Train Night Set Samples", 
                 labels= [f'Index {index}' for index in sample_indices], square=False)
plt.savefig(os.path.join(save_path, 'regularHEsamples.png'))
plt.show()
plt.figure()
img.plot_samples([HE_img[:,:,2] for HE_img in HE_imgs], 
                 title="Histogram Equalized HSV V-Channel Plot of Train Night Set Samples", 
                 labels= [f'Index {index}' for index in sample_indices], square=False)
plt.savefig(os.path.join(save_path, 'regularHEHSVsamples.png'))
plt.show()

# new hist plot
plt.figure(figsize=(11,3))
for i, image in enumerate(HE_imgs):
    plt.subplot(1,3,i+1)
    plt.hist(image[:,:,2].ravel(),256,[0,256], color="darkblue")
    plt.ylabel("Pixel Count")
    plt.xlabel(f"Index {sample_indices[i]} HSV V-Channel Value")
plt.suptitle("Histogram Equalized HSV V-Channel Distributions")
plt.tight_layout()
plt.savefig(os.path.join(save_path, 'regularHEhistograms.png'))
plt.show()

# %% [markdown]
# ## CLAHE Histogram

# %%
clahe = cv2.createCLAHE(clipLimit=2)
CLAHE_imgs = []
for image in HSV_imgs:
    night_img_CLAHE = copy.copy(image)
    night_img_CLAHE[:,:,2] = np.clip(clahe.apply(night_img_CLAHE[:,:,2]), 0, 255).astype(np.uint8)
    CLAHE_imgs.append(night_img_CLAHE)

plt.figure()
img.plot_samples([cv2.cvtColor(CLAHE_img, cv2.COLOR_HSV2RGB) for CLAHE_img in CLAHE_imgs], 
                 title= "CLAHE Equalized Samples from Train Night Set with Clip Limit = 2", 
                 labels= [f'Index {index}' for index in sample_indices],square=False)
plt.savefig(os.path.join(save_path, 'CLAHEsamples.png'))
plt.show()

plt.figure()
img.plot_samples([CLAHE_img[:,:,2] for CLAHE_img in CLAHE_imgs], 
                 title="CLAHE HSV V-Channel Plot of Train Night Set Samples with Clip Limit = 2", 
                 labels= [f'Index {index}' for index in sample_indices],square=False)
plt.savefig(os.path.join(save_path, 'CLAHEHSVplot.png'))
plt.show()

# new hist plot
plt.figure(figsize=(14,3))
for i, image in enumerate(CLAHE_imgs):
    plt.subplot(1,3,i+1)
    plt.hist(image[:,:,2].ravel(),256,[0,256], color="darkblue")
    plt.ylabel("Pixel Count")
    plt.xlabel(f"Index {sample_indices[i]} HSV V-Channel Value")
plt.suptitle("CLAHE Equalized HSV V-Channel Distributions with Clip Limit = 2")
plt.tight_layout()
plt.savefig(os.path.join(save_path, 'CLAHEhistogram.png'))
plt.show()

# %% [markdown]
# ## CLAHE YOLOPX RUN
#
# Since we are not doing any retraining, and using CLAHE purely as a preprocessing step, we will only evaluate CLAHE on the night validation set, with a couple of parametrs for the cliplimit. CLAHE is a massive CPU bottleneck, so first we will transform the relevant validation night images, before using YOLOPX.
#
# ### Transform CLAHE Val Night

# %%
# data_dir = dirs.get_data_dir()
# CLAHE_path = os.path.join(data_dir, "images_CLAHE")
# os.makedirs(CLAHE_path, exist_ok=True)

# %%
# # Run CLAHE on autoencoderKL images
# val_night = os.path.join(dirs.get_data_dir(), "images_AutoencoderKL", "val")

cliplimits = [1, 2, 3]

# for limit in cliplimits:
#     clahe = cv2.createCLAHE(clipLimit=limit)
#     limit_path = os.path.join(CLAHE_path, f"clip_limit_{limit}")
#     os.makedirs(limit_path, exist_ok=True)

#     for image in tqdm(os.listdir(val_night)):
#         night_img_path = os.path.join(val_night, image)
        
#         night_img = cv2.cvtColor(cv2.imread(night_img_path), cv2.COLOR_BGR2HSV)
#         night_img[:,:,2] = np.clip(clahe.apply(night_img[:,:,2]), 0, 255).astype(np.uint8)
#         night_img = cv2.cvtColor(night_img, cv2.COLOR_HSV2BGR)

#         base = os.path.basename(night_img_path)
#         cv2.imwrite(os.path.join(limit_path, base), night_img)

# %% [markdown]
# ### Validation Loop

# %%
yolo = YOLOPX_BDD()

results_dir = os.path.join(dirs.get_base_dir(), 'results')
for limit in cliplimits:
    yolo.config.defrost()
    yolo.set_image_path(f"images_CLAHE/clip_limit_{limit}")
    output_dir = os.path.join(results_dir,f'4_yolopx_CLAHE_night_cliplimit_{limit}')
    os.makedirs(output_dir, exist_ok=True)
    yolo.config.OUTPUT_DIR = output_dir
    yolo.final_output_dir = output_dir
    yolo.config.freeze()
    yolo.validate('night')
# Out:
# AUTO_RESUME: False
# CUDNN:
#   BENCHMARK: True
#   DETERMINISTIC: False
#   ENABLED: True
# DATASET:
#   CLAHE_CLIPLIMIT: 2.0
#   CLAHE_VAL: False
#   COLOR_RGB: False
#   DATAROOT: c:\Users\joche\Development\Github\LightSB_YOLO\data\images
#   DATASET: BddDataset
#   DATA_FORMAT: jpg
#   FLIP: True
#   HSV_H: 0.015
#   HSV_S: 0.7
#   HSV_V: 0.4
#   LABELROOT: c:\Users\joche\Development\Github\LightSB_YOLO\data\bdd\det_annotations
#   LANEROOT: c:\Users\joche\Development\Github\LightSB_YOLO\data\bdd\ll_seg_annotations
#   MASKROOT: c:\Users\joche\Development\Github\LightSB_YOLO\data\bdd\da_seg_annotations
#   ORG_IMG_SIZE: [720, 1280]
#   ROT_FACTOR: 10
#   SCALE_FACTOR: 0.25
#   SELECT_DATA: False
#   SHEAR: 0.0
#   TEST_SET: val
#   TRAIN_SET: train
#   TRANSLATE: 0.1
# DEBUG: False
# GPUS: (0,)
# LOG_DIR: c:\Users\joche\Development\Github\LightSB_YOLO\results\logs
# LOSS:
#   BOX_GAIN: 0.05
#   CLS_GAIN: 0.5
#   CLS_POS_WEIGHT: 1.0
#   DA_SEG_GAIN: 0.2
#   FL_GAMMA: 2.0
#   LL_IOU_GAIN: 0.2
#   LL_SEG_GAIN: 0.2
#   LOSS_NAME:
#   MULTI_HEAD_LAMBDA: None
#   OBJ_GAIN: 1.0
#   OBJ_POS_WEIGHT: 1.0
#   SEG_POS_WEIGHT: 1.0
# METRICS_PER_IMAGE: True
# MODEL:
#   EXTRA:
#
#   HEADS_NAME: ['']
#   IMAGE_SIZE: [640, 640]
#   NAME:
#   PRETRAINED:
#   PRETRAINED_DET:
#   STRU_WITHSHARE: False
# NEED_AUTOANCHOR: False
# OUTPUT_DIR: c:\Users\joche\Development\Github\LightSB_YOLO\results
# PIN_MEMORY: True
# PRINT_FREQ: 2150
# TEST:
#   BATCH_SIZE_PER_GPU: 4
#   MODEL_FILE:
#   NMS_CONF_THRESHOLD: 0.001
#   NMS_IOU_THRESHOLD: 0.6
#   PLOTS: False
#   SAVE_JSON: False
#   SAVE_TXT: True
# TRAIN:
#   ANCHOR_THRESHOLD: 4.0
#   BATCH_SIZE_PER_GPU: 8
#   BEGIN_EPOCH: 0
#   DET_ONLY: False
#   DRIVABLE_ONLY: False
#   ENC_DET_ONLY: False
#   ENC_SEG_ONLY: False
#   END_EPOCH: 200
#   GAMMA1: 0.99
#   GAMMA2: 0.0
#   IOU_THRESHOLD: 0.2
#   LANE_ONLY: False
#   LR0: 0.001
#   LRF: 0.1
#   MOMENTUM: 0.937
#   NESTEROV: True
#   OPTIMIZER: adamw
#   PLOT: False
#   SEG_ONLY: False
#   SHUFFLE: True
#   VAL_FREQ: 20
#   WARMUP_BIASE_LR: 0.1
#   WARMUP_EPOCHS: 3.0
#   WARMUP_MOMENTUM: 0.8
#   WD: 0.0005
# WORKERS: 0
# mixup_rate: 0.15
# mosaic_rate: 0.0
# num_seg_class: 2
# AUTO_RESUME: False
# CUDNN:
#   BENCHMARK: True
#   DETERMINISTIC: False
#   ENABLED: True
# DATASET:
#   CLAHE_CLIPLIMIT: 2.0
#   CLAHE_VAL: False
#   COLOR_RGB: False
#   DATAROOT: c:\Users\joche\Development\Github\LightSB_YOLO\data\images
#   DATASET: BddDataset
#   DATA_FORMAT: jpg
#   FLIP: True
#   HSV_H: 0.015
#   HSV_S: 0.7
#   HSV_V: 0.4
#   LABELROOT: c:\Users\joche\Development\Github\LightSB_YOLO\data\bdd\det_annotations
#   LANEROOT: c:\Users\joche\Development\Github\LightSB_YOLO\data\bdd\ll_seg_annotations
#   MASKROOT: c:\Users\joche\Development\Github\LightSB_YOLO\data\bdd\da_seg_annotations
#   ORG_IMG_SIZE: [720, 1280]
#   ROT_FACTOR: 10
#   SCALE_FACTOR: 0.25
#   SELECT_DATA: False
#   SHEAR: 0.0
#   TEST_SET: val
#   TRAIN_SET: train
#   TRANSLATE: 0.1
# DEBUG: False
# GPUS: (0,)
# LOG_DIR: c:\Users\joche\Development\Github\LightSB_YOLO\results\logs
# LOSS:
#   BOX_GAIN: 0.05
#   CLS_GAIN: 0.5
#   CLS_POS_WEIGHT: 1.0
#   DA_SEG_GAIN: 0.2
#   FL_GAMMA: 2.0
#   LL_IOU_GAIN: 0.2
#   LL_SEG_GAIN: 0.2
#   LOSS_NAME:
#   MULTI_HEAD_LAMBDA: None
#   OBJ_GAIN: 1.0
#   OBJ_POS_WEIGHT: 1.0
#   SEG_POS_WEIGHT: 1.0
# METRICS_PER_IMAGE: True
# MODEL:
#   EXTRA:
#
#   HEADS_NAME: ['']
#   IMAGE_SIZE: [640, 640]
#   NAME:
#   PRETRAINED:
#   PRETRAINED_DET:
#   STRU_WITHSHARE: False
# NEED_AUTOANCHOR: False
# OUTPUT_DIR: c:\Users\joche\Development\Github\LightSB_YOLO\results
# PIN_MEMORY: True
# PRINT_FREQ: 2150
# TEST:
#   BATCH_SIZE_PER_GPU: 4
#   MODEL_FILE:
#   NMS_CONF_THRESHOLD: 0.001
#   NMS_IOU_THRESHOLD: 0.6
#   PLOTS: False
#   SAVE_JSON: False
#   SAVE_TXT: True
# TRAIN:
#   ANCHOR_THRESHOLD: 4.0
#   BATCH_SIZE_PER_GPU: 8
#   BEGIN_EPOCH: 0
#   DET_ONLY: False
#   DRIVABLE_ONLY: False
#   ENC_DET_ONLY: False
#   ENC_SEG_ONLY: False
#   END_EPOCH: 200
#   GAMMA1: 0.99
#   GAMMA2: 0.0
#   IOU_THRESHOLD: 0.2
#   LANE_ONLY: False
#   LR0: 0.001
#   LRF: 0.1
#   MOMENTUM: 0.937
#   NESTEROV: True
#   OPTIMIZER: adamw
#   PLOT: False
#   SEG_ONLY: False
#   SHUFFLE: True
#   VAL_FREQ: 20
#   WARMUP_BIASE_LR: 0.1
#   WARMUP_EPOCHS: 3.0
#   WARMUP_MOMENTUM: 0.8
#   WD: 0.0005
# WORKERS: 0
# mixup_rate: 0.15
# mosaic_rate: 0.0
# num_seg_class: 2
# Num validation "night" images: 3929
# Num validation "night" images: 3929
# New image path:  c:\Users\joche\Development\Github\LightSB_YOLO\data\images_CLAHE/clip_limit_1\b1c81faa-3df17267.jpg
#   0%|          | 0/983 [00:00<?, ?it/s]c:\Users\joche\anaconda3\envs\yolopx_lightsb\lib\site-packages\torch\functional.py:513: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\TensorShape.cpp:3610.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 100%|██████████| 983/983 [07:30<00:00,  2.18it/s]
# Test:    Loss(0.000)
# Driving area Segment: Acc(0.000)    IOU (0.000)    mIOU(0.000)
# Lane line Segment: Acc(0.000)    IOU (0.000)  mIOU(0.000)
# Detect: P(0.023)  R(0.731)  mAP@0.5(0.375)  mAP@0.5:0.95(0.175)
# Time: inference(0.0690s/frame)  nms(0.0058s/frame)
# Test:    Loss(0.000)
# Driving area Segment: Acc(0.000)    IOU (0.000)    mIOU(0.000)
# Lane line Segment: Acc(0.000)    IOU (0.000)  mIOU(0.000)
# Detect: P(0.023)  R(0.731)  mAP@0.5(0.375)  mAP@0.5:0.95(0.175)
# Time: inference(0.0690s/frame)  nms(0.0058s/frame)
#                  all    3.93e+03     3.7e+04      0.0229       0.731       0.375       0.175
# Speed: 0.0/0.0/0.0 ms inference/NMS/total per 640x640 image at batch-size 8
# Results saved to c:\Users\joche\Development\Github\LightSB_YOLO\results\4_yolopx_CLAHE_night_cliplimit_1\predictions
# 3929 labels saved to c:\Users\joche\Development\Github\LightSB_YOLO\results\4_yolopx_CLAHE_night_cliplimit_1\predictions\labels
# Test:    Loss(0.000)
# Driving area Segment: Acc(0.000)    IOU (0.000)    mIOU(0.000)
# Lane line Segment: Acc(0.000)    IOU (0.000)  mIOU(0.000)
# Detect: P(0.023)  R(0.731)  mAP@0.5(0.375)  mAP@0.5:0.95(0.175)
# Time: inference(0.0690s/frame)  nms(0.0058s/frame)
# New image path:  c:\Users\joche\Development\Github\LightSB_YOLO\data\images_CLAHE/clip_limit_2\b1c81faa-3df17267.jpg
# Num validation "night" images: 3929
# Num validation "night" images: 3929
# 100%|██████████| 983/983 [07:29<00:00,  2.19it/s]
# Test:    Loss(0.000)
# Driving area Segment: Acc(0.000)    IOU (0.000)    mIOU(0.000)
# Lane line Segment: Acc(0.000)    IOU (0.000)  mIOU(0.000)
# Detect: P(0.023)  R(0.720)  mAP@0.5(0.367)  mAP@0.5:0.95(0.172)
# Time: inference(0.0692s/frame)  nms(0.0057s/frame)
# Test:    Loss(0.000)
# Driving area Segment: Acc(0.000)    IOU (0.000)    mIOU(0.000)
# Lane line Segment: Acc(0.000)    IOU (0.000)  mIOU(0.000)
# Detect: P(0.023)  R(0.720)  mAP@0.5(0.367)  mAP@0.5:0.95(0.172)
# Time: inference(0.0692s/frame)  nms(0.0057s/frame)
#                  all    3.93e+03     3.7e+04      0.0226        0.72       0.367       0.172
# Speed: 0.0/0.0/0.0 ms inference/NMS/total per 640x640 image at batch-size 8
# Results saved to c:\Users\joche\Development\Github\LightSB_YOLO\results\4_yolopx_CLAHE_night_cliplimit_2\predictions
# 3929 labels saved to c:\Users\joche\Development\Github\LightSB_YOLO\results\4_yolopx_CLAHE_night_cliplimit_2\predictions\labels
# Test:    Loss(0.000)
# Driving area Segment: Acc(0.000)    IOU (0.000)    mIOU(0.000)
# Lane line Segment: Acc(0.000)    IOU (0.000)  mIOU(0.000)
# Detect: P(0.023)  R(0.720)  mAP@0.5(0.367)  mAP@0.5:0.95(0.172)
# Time: inference(0.0692s/frame)  nms(0.0057s/frame)
# New image path:  c:\Users\joche\Development\Github\LightSB_YOLO\data\images_CLAHE/clip_limit_3\b1c81faa-3df17267.jpg
# Num validation "night" images: 3929
# Num validation "night" images: 3929
# 100%|██████████| 983/983 [07:27<00:00,  2.20it/s]
# Test:    Loss(0.000)
# Driving area Segment: Acc(0.000)    IOU (0.000)    mIOU(0.000)
# Lane line Segment: Acc(0.000)    IOU (0.000)  mIOU(0.000)
# Detect: P(0.022)  R(0.710)  mAP@0.5(0.361)  mAP@0.5:0.95(0.168)
# Time: inference(0.0693s/frame)  nms(0.0056s/frame)
# Test:    Loss(0.000)
# Driving area Segment: Acc(0.000)    IOU (0.000)    mIOU(0.000)
# Lane line Segment: Acc(0.000)    IOU (0.000)  mIOU(0.000)
# Detect: P(0.022)  R(0.710)  mAP@0.5(0.361)  mAP@0.5:0.95(0.168)
# Time: inference(0.0693s/frame)  nms(0.0056s/frame)
#                  all    3.93e+03     3.7e+04      0.0223        0.71       0.361       0.168
# Speed: 0.0/0.0/0.0 ms inference/NMS/total per 640x640 image at batch-size 8
# Results saved to c:\Users\joche\Development\Github\LightSB_YOLO\results\4_yolopx_CLAHE_night_cliplimit_3\predictions
# 3929 labels saved to c:\Users\joche\Development\Github\LightSB_YOLO\results\4_yolopx_CLAHE_night_cliplimit_3\predictions\labels
# Test:    Loss(0.000)
# Driving area Segment: Acc(0.000)    IOU (0.000)    mIOU(0.000)
# Lane line Segment: Acc(0.000)    IOU (0.000)  mIOU(0.000)
# Detect: P(0.022)  R(0.710)  mAP@0.5(0.361)  mAP@0.5:0.95(0.168)
# Time: inference(0.0693s/frame)  nms(0.0056s/frame)
